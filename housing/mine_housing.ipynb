# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.options.display.max_columns = 999
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
pd.options.display.max_rows = 999
data.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
# Display numerical correlations between features on heatmap
sns.set(font_scale=1.1)
correlation_train = data.corr()
mask = np.triu(correlation_train.corr())
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_train,
            annot=True,
            fmt='.1f',
            cmap='coolwarm',
            square=True,
            mask=mask,
            linewidths=1,
            cbar=False)

plt.show()

# %%
def missing_percentage(df):
    
    total = df.isnull().sum().sort_values(
        ascending=False)[df.isnull().sum().sort_values(ascending=False) != 0]
    percent = (df.isnull().sum().sort_values(ascending=False) / len(df) *
               100)[(df.isnull().sum().sort_values(ascending=False) / len(df) *
                     100) != 0]
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %%
missing = missing_percentage(data)

fig, ax = plt.subplots(figsize=(20, 5))
sns.barplot(x=missing.index, y='Percent', data=missing, palette='Reds_r')
plt.xticks(rotation=90)

display(missing.T.style.background_gradient(cmap='Reds', axis=1))
# Out:
# <style  type="text/css" >
#     #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col1 {
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col2 {
#             background-color:  #820711;
#             color:  #f1f1f1;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col3 {
#             background-color:  #b81419;
#             color:  #f1f1f1;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col4 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col5 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_4626686e_a093_11ea_ac34_1062e50ed46drow0_col6 {
#             background-color:  #ffece3;
#             color:  #000000;
# ...

# %%
data = data.drop('Id',axis=1)
data = data.drop('Alley',axis=1)
data = data.drop('PoolQC',axis=1)
data = data.drop('Fence',axis=1)
data = data.drop('MiscFeature',axis=1)

# %%
x = data.drop('SalePrice',axis=1)
y = data['SalePrice']

# %%
cols = ["FireplaceQu", "GarageCond", "GarageQual", "GarageFinish", "GarageType", "BsmtCond", "BsmtExposure", "BsmtQual", "BsmtFinType2", "BsmtFinType1"]
x[cols] = x[cols].fillna("None")

# %%
cols = ["GarageYrBlt", "MasVnrArea", "BsmtHalfBath", "BsmtFullBath", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "GarageCars"]
x[cols] = x[cols].fillna(x[cols].mean())

cols = ["MasVnrType", "MSZoning", "Utilities", "Exterior1st", "Exterior2nd", "SaleType", "Electrical", "KitchenQual", "Functional"]
x[cols] = x.groupby("Neighborhood")[cols].transform(lambda x: x.fillna(x.mode()[0]))

cols = ["GarageArea", "LotFrontage"]
x[cols] = x.groupby("Neighborhood")[cols].transform(lambda x: x.fillna(x.mean()))

# %%
pd.options.display.max_rows = 999
x.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
cols = ["MSZoning", "LotArea", "Street", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope", "Neighborhood",
        "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle","RoofMatl","Exterior1st", "Exterior2nd", "MasVnrType",
        "ExterQual", "ExterCond","Foundation","Heating", "HeatingQC","PavedDrive","CentralAir","Electrical","KitchenQual",
        "Functional","SaleType","SaleCondition", "FireplaceQu", "GarageCond", 
        "GarageQual", "GarageFinish", "GarageType", "BsmtCond", "BsmtExposure", "BsmtQual", "BsmtFinType2", "BsmtFinType1"]
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cols:
    x[i] = le.fit_transform(x[i])

# %%
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0      327       1         3            3
# 1          20         3         80.0      498       1         3            3
# 2          60         3         68.0      702       1         0            3
# 3          70         3         60.0      489       1         0            3
# 4          60         3         84.0      925       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0             5           2           2
# 1          0          2          0            24           1           2
# 2          0          4          0             5           2           2
# 3          0          0          0             6           2           2
# 4          0          2          0            15           2           2
#
# ...

# %%
# Creating new features  based on previous observations
x['TotalSF'] = (x['BsmtFinSF1'] + x['BsmtFinSF2'] +
                       x['1stFlrSF'] + x['2ndFlrSF'])
x['TotalBathrooms'] = (x['FullBath'] +
                              (0.5 * x['HalfBath']) +
                              x['BsmtFullBath'] +
                              (0.5 * x['BsmtHalfBath']))

x['TotalPorchSF'] = (x['OpenPorchSF'] + x['3SsnPorch'] +
                            x['EnclosedPorch'] +
                            x['ScreenPorch'] + x['WoodDeckSF'])

x['YearBlRm'] = (x['YearBuilt'] + x['YearRemodAdd'])

# Merging quality and conditions
x['TotalExtQual'] = (x['ExterQual'] + x['ExterCond'])
x['TotalBsmQual'] = (x['BsmtQual'] + x['BsmtCond'] +
                            x['BsmtFinType1'] +
                            x['BsmtFinType2'])
x['TotalGrgQual'] = (x['GarageQual'] + x['GarageCond'])
x['TotalQual'] = x['OverallQual'] + x[
    'TotalExtQual'] + x['TotalBsmQual'] + x[
        'TotalGrgQual'] + x['KitchenQual'] + x['HeatingQC']

# Creating new features by using new quality indicators
x['QualGr'] = x['TotalQual'] * x['GrLivArea']
x['QualBsm'] = x['TotalBsmQual'] * (x['BsmtFinSF1'] +
                                                  x['BsmtFinSF2'])
x['QualPorch'] = x['TotalExtQual'] * x['TotalPorchSF']
x['QualExt'] = x['TotalExtQual'] * x['MasVnrArea']
x['QualGrg'] = x['TotalGrgQual'] * x['GarageArea']
x['QlLivArea'] = (x['GrLivArea'] -
                         x['LowQualFinSF']) * (x['TotalQual'])
x['QualSFNg'] = x['QualGr'] * x['Neighborhood']

# %%
# Creating some simple features
#data_pred['HasPool'] = data_pred['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['Has2ndFloor'] = data_pred['2ndFlrSF'].apply(lambda x: 1
#                                                     if x > 0 else 0)
#data_pred['HasGarage'] = data_pred['QualGrg'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['HasBsmt'] = data_pred['QualBsm'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['HasFireplace'] = data_pred['Fireplaces'].apply(lambda x: 1
#                                                        if x > 0 else 0)
#data_pred['HasPorch'] = data_pred['QualPorch'].apply(lambda x: 1 if x > 0 else 0)

# %%
# Features to drop
to_drop = [
    'Utilities',
    'YrSold',
    'MoSold',
    'ExterQual',
    'BsmtQual',
    'GarageQual',
    'KitchenQual',
    'HeatingQC',
]
# Dropping features
x.drop(columns=to_drop, inplace=True)

# %%
x.shape
# Out:
# (1460, 82)

# %%
#for k in list(x.columns):
#    IQR=np.percentile(x[k],75) - np.percentile(x[k],25)
    
#   Outlier_top=np.percentile(x[k],75)+1.5*IQR
#    Outlier_bottom=np.percentile(x[k],25)-1.5*IQR
#    
#    x[k]=np.where(x[k] > Outlier_top,np.percentile(x[k],50),x[k])
#    x[k]=np.where(x[k] < Outlier_bottom,np.percentile(x[k],50),x[k])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#x_train = sc.fit_transform(x_train)
#x_test = sc.fit_transform(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
model1 = GradientBoostingRegressor()
model1.fit(x_train,y_train)

print(model1.score(x_train,y_train))
print(model1.score(x_test,y_test))
# Out:
# 0.9707215737677851
# 0.8945859310971965

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor()
model2.fit(x_train,y_train)

print(model2.score(x_train,y_train))
print(model2.score(x_test,y_test))
# Out:
# 0.9801228285199254
# 0.8516363640992888

# %%
data_pred = pd.read_csv('test.csv')
data_pred.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
cols = ["PoolQC","MSZoning", "MiscFeature", "Alley", "Fence", "FireplaceQu", "GarageCond", "GarageQual", "GarageFinish", "GarageType", "BsmtCond", "BsmtExposure", "BsmtQual", "BsmtFinType2", "BsmtFinType1"]
data_pred[cols] = data_pred[cols].fillna("None")

# %%
data_pred = data_pred.drop('Id',axis=1)
data_pred = data_pred.drop('Alley',axis=1)
data_pred = data_pred.drop('PoolQC',axis=1)
data_pred = data_pred.drop('Fence',axis=1)
data_pred = data_pred.drop('MiscFeature',axis=1)

# %%
data_pred.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl        NAmes      Feedr       Norm     1Fam
# 1    AllPub    Corner       Gtl        NAmes       Norm       Norm     1Fam
# 2    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
# 4    AllPub    Inside       Gtl      StoneBr       Norm       Norm   TwnhsE
#
# ...

# %%
data_pred.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      227
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          2
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
# BsmtExposure       0
# BsmtFinType1       0
# BsmtFinSF1         1
# BsmtFinType2       0
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         0
# 1stFlrSF           0
# 2ndFlrSF           0
# ...

# %%
cols = ["GarageYrBlt", "MasVnrArea", "BsmtHalfBath", "BsmtFullBath", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "GarageCars"]
data_pred[cols] = data_pred[cols].fillna(x[cols].mean())

cols = ["MasVnrType", "MSZoning", "Utilities", "Exterior1st", "Exterior2nd", "SaleType", "Electrical", "KitchenQual", "Functional"]
data_pred[cols] = data_pred.groupby("Neighborhood")[cols].transform(lambda data_pred: data_pred.fillna(data_pred.mode()[0]))

cols = ["GarageArea", "LotFrontage"]
data_pred[cols] = data_pred.groupby("Neighborhood")[cols].transform(lambda data_pred: data_pred.fillna(data_pred.mean()))

# %%
cols = ["MSZoning", "LotArea", "Street", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope", "Neighborhood",
        "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle","RoofMatl","Exterior1st", "Exterior2nd", "MasVnrType",
        "ExterQual", "ExterCond","Foundation","Heating", "HeatingQC","PavedDrive","CentralAir","Electrical","KitchenQual",
        "Functional","SaleType","SaleCondition", "FireplaceQu", "GarageCond", 
        "GarageQual", "GarageFinish", "GarageType", "BsmtCond", "BsmtExposure", "BsmtQual", "BsmtFinType2", "BsmtFinType1"]
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cols:
    data_pred[i] = le.fit_transform(data_pred[i])

# %%
# Creating new features  based on previous observations
data_pred['TotalSF'] = (data_pred['BsmtFinSF1'] + data_pred['BsmtFinSF2'] +
                       data_pred['1stFlrSF'] + data_pred['2ndFlrSF'])
data_pred['TotalBathrooms'] = (data_pred['FullBath'] +
                              (0.5 * data_pred['HalfBath']) +
                              data_pred['BsmtFullBath'] +
                              (0.5 * data_pred['BsmtHalfBath']))

data_pred['TotalPorchSF'] = (data_pred['OpenPorchSF'] + data_pred['3SsnPorch'] +
                            data_pred['EnclosedPorch'] +
                            data_pred['ScreenPorch'] + data_pred['WoodDeckSF'])

data_pred['YearBlRm'] = (data_pred['YearBuilt'] + data_pred['YearRemodAdd'])

# Merging quality and conditions
data_pred['TotalExtQual'] = (data_pred['ExterQual'] + data_pred['ExterCond'])
data_pred['TotalBsmQual'] = (data_pred['BsmtQual'] + data_pred['BsmtCond'] +
                            data_pred['BsmtFinType1'] +
                            data_pred['BsmtFinType2'])
data_pred['TotalGrgQual'] = (data_pred['GarageQual'] + data_pred['GarageCond'])
data_pred['TotalQual'] = data_pred['OverallQual'] + data_pred[
    'TotalExtQual'] + data_pred['TotalBsmQual'] + data_pred['TotalGrgQual'] + data_pred['KitchenQual'] 
+ data_pred['HeatingQC']

# Creating new features by using new quality indicators
data_pred['QualGr'] = data_pred['TotalQual'] * data_pred['GrLivArea']
data_pred['QualBsm'] = data_pred['TotalBsmQual'] * (data_pred['BsmtFinSF1'] + data_pred['BsmtFinSF2'])
data_pred['QualPorch'] = data_pred['TotalExtQual'] * data_pred['TotalPorchSF']
data_pred['QualExt'] = data_pred['TotalExtQual'] * data_pred['MasVnrArea']
data_pred['QualGrg'] = data_pred['TotalGrgQual'] * data_pred['GarageArea']
data_pred['QlLivArea'] = (data_pred['GrLivArea'] - data_pred['LowQualFinSF']) * (data_pred['TotalQual'])
data_pred['QualSFNg'] = data_pred['QualGr'] * data_pred['Neighborhood']

# %%
# Creating some simple features
#data_pred['HasPool'] = data_pred['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['Has2ndFloor'] = data_pred['2ndFlrSF'].apply(lambda x: 1
#                                                     if x > 0 else 0)
#data_pred['HasGarage'] = data_pred['QualGrg'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['HasBsmt'] = data_pred['QualBsm'].apply(lambda x: 1 if x > 0 else 0)
#data_pred['HasFireplace'] = data_pred['Fireplaces'].apply(lambda x: 1
#                                                        if x > 0 else 0)
#data_pred['HasPorch'] = data_pred['QualPorch'].apply(lambda x: 1 if x > 0 else 0)

# %%
# Features to drop
to_drop = [
    'Utilities',
    'YrSold',
    'MoSold',
    'ExterQual',
    'BsmtQual',
    'GarageQual',
    'KitchenQual',
    'HeatingQC',
]
# Dropping features
data_pred.drop(columns=to_drop, inplace=True)

# %%
data_pred.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          20         3         80.0      777       1         3            3
# 1          20         4         81.0      964       1         0            3
# 2          60         4         74.0      947       1         0            3
# 3          60         4         78.0      587       1         0            3
# 4         120         4         43.0      118       1         0            1
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0          4          0            12           1           2         0
# 1          0          0            12           2           2         0
# 2          4          0             8           2           2         0
# 3          4          0             8           2           2         0
# 4          4          0            22           2           2         4
#
# ...

# %%
predictions = model1.predict(data_pred)

# %%
submission = pd.DataFrame({'SalePrice': predictions})
submission.to_csv('pred3.csv')

# %%
submission.head()
# Out:
#        SalePrice
# 0  134343.698483
# 1  170837.153752
# 2  176618.048038
# 3  191125.030025
# 4  204248.346018
